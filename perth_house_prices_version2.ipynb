# %%
#importing dependencies

import pandas as pd
import os
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
#Loading CSV

df = pd.read_csv(os.path.join("Resources", "perth_house_prices.csv"))

df.head()
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160      2003.0     18300  Cockburn Central Station
# 1        351         139      2013.0     26900           Kwinana Station
# 2        719          86      1979.0     22600           Challis Station
# 3        651          59      1953.0     17900           Midland Station
# 4        466         131      1998.0     11200        Bassendean Station
#
#    NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# 0              1800  09-2018\r      6164 -32.115900  115.842450
# 1              4900  02-2019\r      6167 -32.193470  115.859554
# 2              1900  06-2015\r      6111 -32.120578  115.993579
# 3              3600  07-2018\r      6056 -31.900547  116.038009
# 4              2000  11-2016\r      6054 -31.885790  115.947780
#
#                     NEAREST_SCH  NEAREST_SCH_DIST  NEAREST_SCH_RANK
# 0   LAKELAND SENIOR HIGH SCHOOL          0.828339               NaN
# 1                ATWELL COLLEGE          5.524324             129.0
# 2  KELMSCOTT SENIOR HIGH SCHOOL          1.649178             113.0
# 3  SWAN VIEW SENIOR HIGH SCHOOL          1.571401               NaN
# 4                 KIARA COLLEGE          1.514922               NaN

# %%
#Selecting Columns of interest

df = df[["BUILD_YEAR","BEDROOMS","BATHROOMS","LAND_AREA","FLOOR_AREA","CBD_DIST","NEAREST_SCH_RANK","PRICE"]]
df
# Out:
#        BUILD_YEAR  BEDROOMS  BATHROOMS  LAND_AREA  FLOOR_AREA  CBD_DIST  \
# 0          2003.0         4          2        600         160     18300
# 1          2013.0         3          2        351         139     26900
# 2          1979.0         3          1        719          86     22600
# 3          1953.0         2          1        651          59     17900
# 4          1998.0         4          1        466         131     11200
# ...           ...       ...        ...        ...         ...       ...
# 33651      2013.0         4          3        292         245     16100
# 33652         NaN         3          2        228         114      9600
# 33653         NaN         3          2        261         112      9600
# 33654      1974.0         3          1        457          85     12600
# 33655         NaN         3          1        296          95     16700
#
#        NEAREST_SCH_RANK    PRICE
# 0                   NaN   565000
# 1                 129.0   365000
# 2                 113.0   287000
# 3                   NaN   255000
# 4                   NaN   325000
# ...                 ...      ...
# 33651              49.0  1040000
# 33652              35.0   410000
# 33653              35.0   427000
# 33654               NaN   295000
# 33655              53.0   295000
#
# [33656 rows x 8 columns]

# %%
#Deleting all empty rows
df = df.dropna()
df
# Out:
#        BUILD_YEAR  BEDROOMS  BATHROOMS  LAND_AREA  FLOOR_AREA  CBD_DIST  \
# 1          2013.0         3          2        351         139     26900
# 2          1979.0         3          1        719          86     22600
# 9          1999.0         3          2        552         126      5900
# 11         2003.0         3          2        398         158     36300
# 13         2002.0         4          2        704         247     23100
# ...           ...       ...        ...        ...         ...       ...
# 33646      2009.0         4          3        414         277      9400
# 33648      2011.0         3          2        248         108     24900
# 33649      2014.0         4          2        400         132     17100
# 33650      1997.0         3          2        200         127     16000
# 33651      2013.0         4          3        292         245     16100
#
#        NEAREST_SCH_RANK    PRICE
# 1                 129.0   365000
# 2                 113.0   287000
# 9                  29.0   685000
# 11                 39.0   367500
# 13                129.0   535000
# ...                 ...      ...
# 33646              24.0  1700000
# 33648             129.0   423000
# 33649              53.0   467000
# 33650             128.0   955000
# 33651              49.0  1040000
#
# [20692 rows x 8 columns]

# %%
# Outputting Dataframe into CSV

df.to_csv('file_name.csv', index=False)

# %%
# Prepocessing data

X = df[["BUILD_YEAR","BEDROOMS","BATHROOMS","LAND_AREA","FLOOR_AREA","CBD_DIST","NEAREST_SCH_RANK"]]
y = df["PRICE"].values.reshape(-1,1)
print(X.shape, y.shape)
# Out:
# (20692, 7) (20692, 1)

# %%
# # Creting a copy of data
# data = X.copy()

# %%
# # Creating dummies for SUBURB column

# data_binary_encoded = pd.get_dummies(data, columns = ["SUBURB"])
# data_binary_encoded

# %%
# data = X.copy()

# data_binary_encoded = pd.get_dummies(X)
# data_binary_encoded.head()

# %%
# Splitting data into training data

from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,y)

# %%
# Scaling data

from sklearn.preprocessing import StandardScaler

X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
# Transforming Data

X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# Linear Regression

from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
# Out:
# LinearRegression()

# %%
# Finding model accuracy using R^2 score

model.score(X_test_scaled, y_test_scaled)
# Out:
# 0.5973000083147635

# %%
predictions = model.predict(X_test_scaled)

plt.scatter(predictions,predictions - y_test_scaled)
plt.hlines(y=0, xmin=predictions.min(), xmax=predictions.max())
plt.show()
